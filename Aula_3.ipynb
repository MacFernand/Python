# %% [markdown]
# <a href="https://colab.research.google.com/github/MacFernand/Python/blob/master/Aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Montando o driver

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Tabela de dados

# %%
# %load_ext google.colab.data_table

# %%
from google.colab import data_table

# %% [markdown]
# Importando Bibliotecas

# %%
import pandas as pd
import random as rd
import numpy  as np

# %% [markdown]
# Importando banco de dados

# %%
df_promo = pd.read_csv('/content/sample_data/CAR.csv', sep=';')

# %%
df_ = pd.read_csv('/content/drive/My Drive/Projetos/Promofarma/Base/FUNCIONA.txt', sep='\t')

# %%
df_ban = pd.read_csv('/content/drive/My Drive/Projetos/Bras/BANCOS.txt', sep=';')

# %%
df_func = pd.read_csv('/content/drive/My Drive/Projetos/Bras/FUNCIONA.txt', sep=';')

# %% [markdown]
# Manipulando dados

# %%
df_promo

# %%
df_.head(5)

# %%
df_ban

# %%
df_func

# %%
type(df_func)
# Out:
# pandas.core.frame.DataFrame

# %%
# Show last few rows
list(df_func)

# %%
# Data type of each column
df_func.tail
# Out:
# <bound method NDFrame.tail of      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 0         202          1  ...                            0                NaN
# 1         202          2  ...                            0                NaN
# 2         202          3  ...                            0                NaN
# 3         202          4  ...                            0                NaN
# 4         202          5  ...                            0                NaN
# ..        ...        ...  ...                          ...                ...
# 127       202    3193717  ...                            0                NaN
# 128       203          1  ...                            0                NaN
# 129       203          2  ...                            0                NaN
# 130       203          3  ...                            0                NaN
# 131       203          4  ...                            0                NaN
#
# ...

# %%
# Return number of columns and rows of dataframe
df_func.shape
# Out:
# (132, 208)

# %%
#  Number of rows
len(df_func.index)
# Out:
# 132

# %%
# Number of columns

len(df_func.columns)
# Out:
# 208

# %%
# Basic statistics
df_func.describe()
# Out:
#          FUCODEMP  ...  FUMATRICULAESOCIAL
# count  132.000000  ...                 0.0
# mean   202.030303  ...                 NaN
# std      0.172073  ...                 NaN
# min    202.000000  ...                 NaN
# 25%    202.000000  ...                 NaN
# 50%    202.000000  ...                 NaN
# 75%    202.000000  ...                 NaN
# max    203.000000  ...                 NaN
#
# [8 rows x 159 columns]

# %%
# Extract first three rows

df_func[0:3]

   # or
    
df_func.iloc[:3]
# Out:
#    FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 0       202          1  ...                            0                NaN
# 1       202          2  ...                            0                NaN
# 2       202          3  ...                            0                NaN
#
# [3 rows x 208 columns]

# %%
# Filter for black hair

df_func[df_func['FUCBO']=="411010"]

     # or
    
df_func.query("FUCBO =='411010'")
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 0         202          1  ...                            0                NaN
# 1         202          2  ...                            0                NaN
# 2         202          3  ...                            0                NaN
# 3         202          4  ...                            0                NaN
# 4         202          5  ...                            0                NaN
# 5         202          6  ...                            0                NaN
# 6         202          7  ...                            0                NaN
# 7         202          8  ...                            0                NaN
# ...

# %%
# Filter for males who have black hair

df_func[(df_func['FUCODSITU']=="48")  & (df_func["FUSEXFUNC"]=="M")]

   # or

df_func.query("FUCODSITU == '48' & FUSEXFUNC =='M'")
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#    FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 1       202          2  ...                            0                NaN
# 4       202          5  ...                            0                NaN
# 5       202          6  ...                            0                NaN
# 6       202          7  ...                            0                NaN
#
# [4 rows x 208 columns]

# %%
# Filter for those who have brown eye or black hair

z = df_func[(df_func['FUCODSITU']=="48") | (df_func["FUBAIRRO"]=="MEIER")]

   # or
z = df_func.query("FUCODSITU == '48' | FUBAIRRO =='MEIER'")

z.head(6)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#    FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 0       202          1  ...                            0                NaN
# 1       202          2  ...                            0                NaN
# 2       202          3  ...                            0                NaN
# 4       202          5  ...                            0                NaN
# 5       202          6  ...                            0                NaN
# 6       202          7  ...                            0                NaN
#
# [6 rows x 208 columns]

# %%
# Filter for eye color of blue, hazel and green

df_func[df_func.Eye.isin(['MEIER','ENGENHO NOVO','BENFICA'])].head()

# %%
# Select one column
df_func[["FUBAIRRO"]].head()

    # or

df_func.FUBAIRRO.head()
# Out:
# 0            MEIER
# 1     ENGENHO NOVO
# 2          BENFICA
# 3           LEBLON
# 4    SAO CRISTOVAO
# Name: FUBAIRRO, dtype: object

# %%
# Select two columns

df_func[["FUCODSITU","FUSEXFUNC"]].head()
# Out:
#    FUCODSITU FUSEXFUNC
# 0         48         F
# 1         48         M
# 2         48         F
# 3         49         F
# 4         48         M

# %%
# Unique Eye colors

df_func["FUBAIRRO"].unique()
# Out:
# array(['MEIER', 'ENGENHO NOVO', 'BENFICA', 'LEBLON', 'SAO CRISTOVAO',
#        'IRAJA', 'FONSECA', 'MESQUITA', 'BARRA DA TIJUCA', 'TIJUCA',
#        'VILA ISABEL', 'HIGIENOPOLIS', 'ANDRADE ARAUJO', 'JACAREPAGUA',
#        'FREGUESIA / JACAREPAGUA', 'JABOUR', 'BOTAFOGO', 'JARDIM BOTANICO',
#        'BENTO RIBEIRO', 'ANIL', 'CAMPO GRANDE', 'SARGENTO RONCALLI',
#        'ROCHA MIRANDA', 'RICARDO DE ALBUQUERQ', 'TOMAS COELHO',
#        'COPACABANA', 'FLAMENGO', 'CAMPOS ELISEOS', 'ANIL - JACAREPAGUA',
#        'RAMOS', 'PARADA QUARENTA', 'JARDIM ESPLANADA', 'BELA VISTA',
#        'FREGUESIA/JACAREPAGUA', 'FREGUESIA JACAREPAGU', 'ITAIPU',
#        'CACHAMBI', 'VILA DA PENHA', 'ABOLIÇÃO', 'ICARAI', 'CENTRO',
#        'GRAJAU', 'RIO COMPRIDO', 'CIDADE DE DEUS', 'MUTONDO', 'RIACHUELO',
#        'BONSUCESSO', 'NILÓPOLIS', 'PECHINCHA', 'BANGU', 'CORDOVIL',
#        'LARANJEIRAS', 'IPANEMA', 'INGA', 'IRAJÁ',
#        'RECREIO DOS BANDEIRANTES', 'GAVEA', 'OSWALDO CRUZ', 'OLARIA',
# ...

# %%
# Maximum of the "Freq" column

df_func.FUCODSITU.max()
# Out:
# 58

# %%
# Call functions on multiple columns 

import numpy as np

pd.DataFrame({'Max_freq': [df_func.FUCODSITU.max()], \
             'Min_freq': [df_func.FUCODSITU.min()],\
             'Std_freq': [np.std(df_func.FUCODSITU)]})
# Out:
#    Max_freq  Min_freq   Std_freq
# 0        58         1  12.711995

# %%
# Maximum Frequency by Sex

df_func.groupby("FUSEXFUNC").agg({"FUCODSITU":"max"})
# Out:
#            FUCODSITU
# FUSEXFUNC
#                    2
# F                 49
# M                 58

# %%
# Count by Bairro Sexo and Sexo

df_func.groupby(["FUBAIRRO","FUSEXFUNC"]).agg({"FUCODSITU":"count"}).rename(columns={"FUCODSITU":"Count"}).head(50)
# Out:
#                                    Count
# FUBAIRRO                FUSEXFUNC
# ABOLIÇÃO                F              1
# ANDARAI                 M              1
# ANDRADE ARAUJO          M              1
# ANIL                    F              1
# ANIL - JACAREPAGUA      F              1
# BANGU                   F              1
# BARRA DA TIJUCA         F              5
#                         M              4
# BELA VISTA              M              1
# BENFICA                 F              1
# BENTO RIBEIRO           M              2
# BONSUCESSO              M              2
# BOTAFOGO                F              5
#                         M              1
# CACHAMBI                F              1
# CAMPO GRANDE            F              1
# CAMPOS ELISEOS          M              1
# CATETE                  M              1
# CENTRO                  M              2
# CIDADE DE DEUS          M              1
# COPACABANA              F              5
# ...

# %%
# Call functions for grouping

df_func.assign(FUSEXFUNC = (df_func.FUCODSITU > 50)).groupby("FUSEXFUNC").agg({"FUSEXFUNC":"count"})\
.rename(columns ={"FUSEXFUNC":"Count"})
# Out:
#            Count
# FUSEXFUNC
# False        130
# True           2

# %%
# Return the first occurance

df_func.query("FUBAIRRO == 'MEIER'")[:1]
# Out:
#    FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 0       202          1  ...                            0                NaN
#
# [1 rows x 208 columns]

# %%
# Return the last occurance

df_func.query("FUBAIRRO == 'MEIER'")[-1:]
# Out:
#      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 115       202    3193705  ...                            0                NaN
#
# [1 rows x 208 columns]

# %%
# Return a count

df_func[df_func.FUBAIRRO.isin(['MEIER','IPANEMA']) & (df_func.FUSEXFUNC=="M")].shape[0]
# Out:
# 4

# %%
# Count for each group

df_func[df_func.FUBAIRRO.isin(['MEIER','IPANEMA']) & (df_func.FUSEXFUNC=="M")].\
groupby(["FUBAIRRO","FUSEXFUNC"]).agg({"FUCODSITU":"count"}).rename(columns={"FUCODSITU":"Count"})
# Out:
#                     Count
# FUBAIRRO FUSEXFUNC
# IPANEMA  M              1
# MEIER    M              3

# %%
# Order in ascending order

df_func.sort_values(by='FUCODSITU').tail(6)
# Out:
#      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 2         202          3  ...                            0                NaN
# 1         202          2  ...                            0                NaN
# 7         202          8  ...                            0                NaN
# 3         202          4  ...                            0                NaN
# 109       202    3193699  ...                            0                NaN
# 123       202    3193713  ...                            0                NaN
#
# [6 rows x 208 columns]

# %%
# Order in descending order

df_func.sort_values(by='FUCODSITU', ascending = False).tail(6)
# Out:
#      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 107       202    3193697  ...                            0                NaN
# 108       202    3193698  ...                            0                NaN
# 83        202    3193673  ...                            0                NaN
# 81        202    3193671  ...                            0                NaN
# 11        202    3190528  ...                            0                NaN
# 55        202    3193420  ...                            0                NaN
#
# [6 rows x 208 columns]

# %%
# "FUCODSITU" in descending and "FUSEXFUNC" in ascending

df_func.sort_values(by=['FUCODSITU','FUSEXFUNC'], ascending = [False,True]).tail(50)
# Out:
#      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 53        202    3193403  ...                            0                NaN
# 63        202    3193527  ...                            0                NaN
# 66        202    3193551  ...                            0                NaN
# 69        202    3193586  ...                            0                NaN
# 74        202    3193632  ...                            0                NaN
# 79        202    3193669  ...                            0                NaN
# 91        202    3193681  ...                            0                NaN
# 94        202    3193684  ...                            0                NaN
# 72        202    3193616  ...                            0                NaN
# 130       203          3  ...                            0                NaN
# 128       203          1  ...                            0                NaN
# ...

# %%
# Rename columns

df_func.rename(columns = {"FUCODSITU":"SITUACAO","FUSEXFUNC":"SEXO"}).tail()
# Out:
#      FUCODEMP  FUMATFUNC  ... FUTIPOINSCEMPREGADORSUCESSAO FUMATRICULAESOCIAL
# 127       202    3193717  ...                            0                NaN
# 128       203          1  ...                            0                NaN
# 129       203          2  ...                            0                NaN
# 130       203          3  ...                            0                NaN
# 131       203          4  ...                            0                NaN
#
# [5 rows x 208 columns]
